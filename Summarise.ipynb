# %%
# !pip install openai python-docx requests
# Out:
# Requirement already satisfied: openai in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (1.91.0)
# Requirement already satisfied: python-docx in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: requests in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from openai) (2.11.3)
# Requirement already satisfied: sniffio in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from openai) (4.12.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: lxml>=3.1.0 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from python-docx) (5.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/parakhagrawal/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests) (2.3.0)

# %%
import requests
from storage import upload_file

# GSK OAuth URL and client credentials
token_url = "https://federation-qa.gsk.com/as/token.oauth2"
client_id = "eb98c3a954444f91a887dc054dd2037c"
client_secret = "XJJVX1bKrQ1YznWfzHunzVhTkQJP2I3wivNjBG2k2rJlHQNIDVV1AwL7TABtAZtcaMF4"

# Request token
response = requests.post(
    token_url,
    data={
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret
    }
)

# Parse token
access_token = response.json()["access_token"]
print("✅ Access token received")
# Out:
# ✅ Access token received

# %%
# GSK Enterprise OpenAI Endpoint
endpoint = "https://dev.api.gsk.com/co/edap/openaidevtest02/openai/deployments/gpt-4o/chat/completions?api-version=2025-01-01-preview"

# Headers with OAuth token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# %%
import json

def summarize_field(field, matched_paragraph):
    prompt = f"""
You are an AI assistant generating a summary for a clinical report.

Summarize the following paragraph as a proper response to the field '{field}'.

For numerical fields, only return numbers. 

Paragraph:
{matched_paragraph}

Summary:
"""

    # Prepare payload
    payload = {
        "messages": [
            {"role": "user", "content": prompt}
        ],
        "temperature": 0.5
    }

    # Send request to GSK OpenAI endpoint
    response = requests.post(endpoint, headers=headers, data=json.dumps(payload))
    result = response.json()

    return result["choices"][0]["message"]["content"].strip()

# %%
import json

# Load matched_paragraphs from semantic_matching.json (from Day 2 output)
with open("matched_paragraphs.json", "r") as f:
    matched_paragraphs = json.load(f)

# %%
final_summaries = {}

for field, paragraph in matched_paragraphs.items():
    print(f"\n🟩 FIELD: {field}")
    print("🔍 Matched Paragraph:\n", paragraph)

    summary = summarize_field(field, paragraph)
    print("📝 Summary:\n", summary)

    final_summaries[field] = summary
# Out:
# 🟩 FIELD: Protocol Summary - Master Disclosure Document for Interventional Studies
# 🔍 Matched Paragraph:
#  6.	STUDY INTERVENTION(S) AND CONCOMITANT THERAPY	46
# 📝 Summary:
#  Study Interventions: 6
# Concomitant Therapy: 46
#
# 🟩 FIELD: The Information on this page will not be posted
# 🔍 Matched Paragraph:
#  PAGE
# 📝 Summary:
#  The information provided on this page is not intended for publication or sharing.
#
# 🟩 FIELD: Before using this template for authoring, refer to the supplemental instructions on Find-IT. This template is used for ALL Interventional studies that evaluate the safety, efficacy or effectiveness of a GSK product.
# Master Disclosure Document (MDD) serves as the source document to disclose protocol related information across different clinical trial registers (e.g. ClinicalTrials.gov, EU Clinical Trials Information System (EU CTIS) and/or GSK/ViiV Clinical Study Register) as required by external regulations and/or GSK policy. Check in TMF for the latest version of the template before initiating a new MDD. As information from the approved MDD will be disclosed on publicly available clinical trial register(s) as required by applicable regulations and GSK policy, minimize inclusion of information that may be considered commercially confidential.
# 🔍 Matched Paragraph:
#  The key design elements of this protocol and results summaries will be posted on www.ClinicalTrials.gov and/or GSK Clinical Study Register in compliance with applicable regulations/GSK policy. GSK will aim to register protocols summaries prior to study start and target results summaries submission within 12 months of primary/ study completion date. Where external regulations require earlier disclosure, GSK will follow those timelines.
# 📝 Summary:
#  Key design elements and results summaries will be disclosed on www.ClinicalTrials.gov and/or GSK Clinical Study Register per regulations/GSK policy. Protocol summaries are targeted for registration prior to study start, and results summaries submission is aimed within 12 months of primary/study completion. Earlier disclosure timelines will be followed if required by external regulations.
#
# 🟩 FIELD: Title of study
# 🔍 Matched Paragraph:
#  STUDY DESIGN
# 📝 Summary:
#  Title of study: Observational study analyzing clinical outcomes and treatment efficacy in a patient cohort.
#
# 🟩 FIELD: Study identifier /CTMS number
# 🔍 Matched Paragraph:
#  STUDY DESIGN
# 📝 Summary:
#  This section does not provide specific numerical identifiers like CTMS numbers. Please ensure the correct field is referenced.
#
# 🟩 FIELD: European Union (EU) Clinical Trial Regulation (EU CTR) number (if applicable)
# 🔍 Matched Paragraph:
#  Providing oversight of the conduct of the study at the site and adherence to requirements of 21 Code of Federal Regulation (CFR), ICH guidelines, the IRB/IEC, European regulation 536/2014 for clinical studies (if applicable), and all other applicable local regulations
# 📝 Summary:
#  536/2014
#
# 🟩 FIELD: Is this an Applicable Clinical Trial (ACT)?
# 🔍 Matched Paragraph:
#  The participant has participated in a clinical trial and has received an investigational product within the following time period prior to the first dosing day in the current study: 3 months, 5 half-lives or twice the duration of the biological effect of the investigational product (whichever is longer).
# 📝 Summary:
#  Yes, this is an Applicable Clinical Trial (ACT).
#
# 🟩 FIELD: Trial registers where the study will be disclosed
# 🔍 Matched Paragraph:
#  STUDY ASSESSMENTS AND PROCEDURES
# 📝 Summary:
#  Trial registers where the study will be disclosed: The study will be registered on ClinicalTrials.gov and the European Union Clinical Trials Register (EudraCT).
#
# 🟩 FIELD: MDD version date
# 🔍 Matched Paragraph:
#  Dates of administration including start and end dates
# 📝 Summary:
#  Start and end dates of administration.
#
# 🟩 FIELD: Approver:
# 🔍 Matched Paragraph:
#  10.1.3.	Informed consent process	69
# 📝 Summary:
#  Approver: 69
#
# 🟩 FIELD: Clinical Lead/equivalent
# 🔍 Matched Paragraph:
#  Participant safety will be continuously monitored by the Sponsor’s Medical Monitor, and designated Safety Lead (or delegate) throughout the study. Pertinent findings and conclusions are shared with the product’s safety review team for review of the overall benefit-risk profile of the product.
# 📝 Summary:
#  The Sponsor’s Medical Monitor and designated Safety Lead (or delegate) will oversee participant safety throughout the study, sharing relevant findings with the safety review team to evaluate the product's benefit-risk profile.
#
# 🟩 FIELD: Section # and Name of the field
# {Add section number and name}
# 🔍 Matched Paragraph:
#  Medical Monitor Name and Contact Information:
# 📝 Summary:
#  Section # and Name of the field
# {Medical Monitor Name and Contact Information}
#
# 🟩 FIELD: Unique Protocol ID
# 🔍 Matched Paragraph:
#  Protocol Title:
# 📝 Summary:
#  Protocol Title
#
# 🟩 FIELD: Brief title
# 🔍 Matched Paragraph:
#  Brief Title:
# 📝 Summary:
#  Summary of Clinical Report
#
# 🟩 FIELD: Acronym
# 🔍 Matched Paragraph:
#  LIST OF ABBREVIATIONS AND DEFINITIONS OF TERMS
# 📝 Summary:
#  LIST OF ABBREVIATIONS AND DEFINITIONS OF TERMS
#
# 🟩 FIELD: CTMS abbreviated title [EU only]
# 🔍 Matched Paragraph:
#  LIST OF ABBREVIATIONS AND DEFINITIONS OF TERMS
# 📝 Summary:
#  LIST OF ABBREVIATIONS AND DEFINITIONS
#
# 🟩 FIELD: Official title of the trial
# 🔍 Matched Paragraph:
#  Brief Title:
# 📝 Summary:
#  Please provide the paragraph you would like summarized for the field "Official title of the trial."
#
# 🟩 FIELD: Secondary IDs
# 🔍 Matched Paragraph:
#  Secondary estimands
# 📝 Summary:
#  Secondary estimands refer to additional measures or analyses that complement the primary estimand in a clinical study. These may provide further insights into treatment effects, subpopulations, or alternative endpoints.
#
# 🟩 FIELD: Secondary ID type
# 🔍 Matched Paragraph:
#  Secondary estimands
# 📝 Summary:
#  Secondary ID type: Secondary estimands
#
# 🟩 FIELD: Sponsor
# 🔍 Matched Paragraph:
#  Sponsor Signatory:
# 📝 Summary:
#  The paragraph does not provide specific information about the sponsor. Please provide additional details for an accurate summary.
#
# 🟩 FIELD: Collaborators
# 🔍 Matched Paragraph:
#  Activity
# 📝 Summary:
#  Collaborators: The section does not provide specific information regarding collaborators.
#
# 🟩 FIELD: Brief summary
# 🔍 Matched Paragraph:
#  Brief Title:
# 📝 Summary:
#  Brief summary: No information provided.
#
# 🟩 FIELD: Detailed description
# 🔍 Matched Paragraph:
#  Synopsis
# 📝 Summary:
#  Please provide the paragraph you'd like summarized, and I will generate a concise summary for the "Detailed description" field.
#
# 🟩 FIELD: Main objective(s) [EU only]
# 🔍 Matched Paragraph:
#  Objectives, Endpoints, and Estimands:
# 📝 Summary:
#  To evaluate the efficacy, safety, and tolerability of the investigational product in the target population, focusing on predefined clinical endpoints and estimands to measure treatment outcomes.
#
# 🟩 FIELD: Secondary objective(s) [EU only]
# 🔍 Matched Paragraph:
#  OBJECTIVES, ENDPOINTS AND ESTIMANDS
# 📝 Summary:
#  Secondary objective(s) [EU only]: Identify additional clinical endpoints and estimands to evaluate secondary outcomes beyond the primary objective.
#
# 🟩 FIELD: Data monitoring committee
# 🔍 Matched Paragraph:
#  Data Monitoring/Other Committee:
# 📝 Summary:
#  The Data Monitoring Committee oversees patient safety and study integrity, reviews interim data, and provides recommendations for trial continuation, modification, or termination.
#
# 🟩 FIELD: Keywords
# 🔍 Matched Paragraph:
#  REFERENCES
# 📝 Summary:
#  Keywords: References, citations, literature, sources
#
# 🟩 FIELD: Medical condition(s) investigated [EU only]
# 🔍 Matched Paragraph:
#  Abnormal laboratory findings associated with the underlying disease are not considered clinically significant unless judged by the Investigator to be more severe than expected for the participant’s condition.
# 📝 Summary:
#  Abnormal laboratory findings related to the underlying disease, unless deemed unusually severe by the Investigator, are not considered clinically significant.
#
# 🟩 FIELD: Therapeutic area [EU only]
# 🔍 Matched Paragraph:
#  Providing oversight of the conduct of the study at the site and adherence to requirements of 21 Code of Federal Regulation (CFR), ICH guidelines, the IRB/IEC, European regulation 536/2014 for clinical studies (if applicable), and all other applicable local regulations
# 📝 Summary:
#  Therapeutic area [EU only]: Adherence to European regulation 536/2014 for clinical studies and applicable local regulations.
#
# 🟩 FIELD: Rare disease [EU only]
# 🔍 Matched Paragraph:
#  Abnormal laboratory findings associated with the underlying disease are not considered clinically significant unless judged by the Investigator to be more severe than expected for the participant’s condition.
# 📝 Summary:
#  Abnormal laboratory findings related to the underlying rare disease are not deemed clinically significant unless the Investigator determines they exceed the expected severity for the participant's condition.
#
# 🟩 FIELD: Primary purpose
# 🔍 Matched Paragraph:
#  Reason for use
# 📝 Summary:
#  The primary purpose is to outline the reason for the clinical intervention or treatment.
#
# 🟩 FIELD: Study Phase
# 🔍 Matched Paragraph:
#  STUDY DESIGN
# 📝 Summary:
#  Phase 3
#
# 🟩 FIELD: Type of human pharmacology (Phase 1) study (EU only)
# 🔍 Matched Paragraph:
#  Pharmacodynamics
# 📝 Summary:
#  Pharmacodynamics study.
#
# 🟩 FIELD: Interventional study model
# 🔍 Matched Paragraph:
#  Study intervention(s) administered
# 📝 Summary:
#  The study utilizes a single-group interventional model where participants receive a specific intervention without a comparison group.
#
# 🟩 FIELD: Allocation
# 🔍 Matched Paragraph:
#  Committees structure
# 📝 Summary:
#  Committees structure not relevant to 'Allocation'.
#
# 🟩 FIELD: Anticipated date of results (EU only)
# 🔍 Matched Paragraph:
#  Table 6	Timeframes for submitting SAE, pregnancy and other events reports to GSK	63
# 📝 Summary:
#  63
#
# 🟩 FIELD: Number of arms
# 🔍 Matched Paragraph:
#  Number of Participants:
# 📝 Summary:
#  1
#
# 🟩 FIELD: Masking type
# (EU only)
# 🔍 Matched Paragraph:
#  Blinding/Masking
# 📝 Summary:
#  Masking Type: Blinded
#
# 🟩 FIELD: Masking description / Blinding implementation details
# 🔍 Matched Paragraph:
#  Blinding/Masking
# 📝 Summary:
#  Blinding was implemented by ensuring that participants, investigators, and outcome assessors were unaware of group assignments throughout the study. Identical placebo and active treatments were used to maintain blinding. Randomization codes were securely stored and only revealed after data analysis was completed.
#
# 🟩 FIELD: Arms
# Repeat below rows depending on number of arms
# 🔍 Matched Paragraph:
#  Exclusion criteria
# 📝 Summary:
#  Exclusion criteria are not relevant to the 'Arms' field. Please provide details specific to study arms for summarization.
#
# 🟩 FIELD: Arm / Group Label
# 🔍 Matched Paragraph:
#  Not applicable as this is an open-label study.
# 📝 Summary:
#  Open-label study
#
# 🟩 FIELD: Arm / Group description
# 🔍 Matched Paragraph:
#  The estimand is described by the following attributes:
# 📝 Summary:
#  The estimand is characterized by specific attributes relevant to the study's objectives and analysis.
#
# 🟩 FIELD: Interventions
# Repeat below rows depending on number of interventions
# 🔍 Matched Paragraph:
#  Table 4	Study intervention administered.
# 📝 Summary:
#  Intervention: Study intervention administered.
#
# 🟩 FIELD: Intervention name
# 🔍 Matched Paragraph:
#  Study intervention(s) administered
# 📝 Summary:
#  Study intervention(s) administered
#
# 🟩 FIELD: Intervention description
# 🔍 Matched Paragraph:
#  Assignment to study intervention
# 📝 Summary:
#  Assignment to study intervention involved randomization of participants to receive either the experimental treatment or the control intervention, ensuring balanced allocation across groups.
#
# 🟩 FIELD: Other names
# 🔍 Matched Paragraph:
#  REFERENCES
# 📝 Summary:
#  "REFERENCES" is not a proper response for the field 'Other names.' No relevant information is contained in the provided paragraph to summarize for this field.
#
# 🟩 FIELD: Relationship between Arms & Interventions
# Repeat below rows depending on number of arms)
# 🔍 Matched Paragraph:
#  Table 4	Study intervention administered.	48
# 📝 Summary:
#  Relationship between Arms & Interventions:
# Study intervention administered: 48
#
# 🟩 FIELD: Arm
# 🔍 Matched Paragraph:
#  APPENDIX
# 📝 Summary:
#  APPENDIX
#
# Arm: Not specified.
#
# 🟩 FIELD: Outcome measure type
# 🔍 Matched Paragraph:
#  Assessment of outcomes
# 📝 Summary:
#  Outcome measure type: The assessment included both qualitative measures, such as patient-reported outcomes and observational analyses, and quantitative measures, including numerical scores derived from standardized scales.
#
# 🟩 FIELD: Outcome measure title
# 🔍 Matched Paragraph:
#  Assessment of outcomes
# 📝 Summary:
#  Assessment of outcomes
#
# 🟩 FIELD: Outcome measure description
# 🔍 Matched Paragraph:
#  Assessment of outcomes
# 📝 Summary:
#  Assessment of outcomes involved evaluating changes in clinical parameters, patient-reported outcomes, and overall treatment efficacy using standardized scales and validated tools.
#
# 🟩 FIELD: Time frame
# 🔍 Matched Paragraph:
#  * Timeframe allowed after receipt or awareness of the information by the Investigator/site staff.
# 📝 Summary:
#  30 days
#
# 🟩 FIELD: Sex
# 🔍 Matched Paragraph:
#  Activity
# 📝 Summary:
#  The paragraph provided does not contain information relevant to the field 'Sex.'
#
# 🟩 FIELD: Gender based
# 🔍 Matched Paragraph:
#  Women in the following categories are considered WONCBP:
# 📝 Summary:
#  Women of Non-Childbearing Potential (WONCBP) are defined as females who meet specific criteria excluding them from the potential to conceive.
#
# 🟩 FIELD: Age Limits
# 🔍 Matched Paragraph:
#  Male or female 18 to 65 years, at the time of signing the informed consent form.
# 📝 Summary:
#  18-65
#
# 🟩 FIELD: Age ranges (EU only)
# 🔍 Matched Paragraph:
#  Male or female 18 to 65 years, at the time of signing the informed consent form.
# 📝 Summary:
#  18-65
#
# 🟩 FIELD: Accepts healthy volunteers
# 🔍 Matched Paragraph:
#  Not applicable as this is a healthy volunteer study.
# 📝 Summary:
#  Yes
#
# 🟩 FIELD: Study population types (EU only)
# 🔍 Matched Paragraph:
#  STUDY POPULATION
# 📝 Summary:
#  Summary:
# The study population consists of individuals from the European Union (EU) categorized into specific types, including healthy volunteers, patients with pre-existing conditions, and individuals undergoing specific medical treatments.
#
# 🟩 FIELD: Inclusion criteria
# 🔍 Matched Paragraph:
#  Inclusion criteria
# 📝 Summary:
#  Summary:
# Patients aged 18–65 years with a confirmed diagnosis of the target condition, able to provide informed consent, and willing to comply with study procedures were included.
#
# 🟩 FIELD: Exclusion criteria
# 🔍 Matched Paragraph:
#  Exclusion criteria
# 📝 Summary:
#  Patients were excluded if they had a history of severe allergic reactions, uncontrolled chronic illnesses, active infections, pregnancy, or were under 18 years of age.
#
# 🟩 FIELD: Study Termination / Cancellation
# 🔍 Matched Paragraph:
#  For study termination:
# 📝 Summary:
#  The study was terminated due to [reason for termination, e.g., lack of participant enrollment, safety concerns, or insufficient funding].
#
# 🟩 FIELD: Recruitment status
# 🔍 Matched Paragraph:
#  Recruitment strategy
# 📝 Summary:
#  Recruitment status: Recruitment is ongoing.
#
# 🟩 FIELD: Why study stopped
# 🔍 Matched Paragraph:
#  Discontinuation of study intervention
# 📝 Summary:
#  The study intervention was discontinued due to safety concerns and adverse events observed in participants.
#
# 🟩 FIELD: Investigational New Drug Application (IND)/Investigational Device Exemption (IDE) Information
# 🔍 Matched Paragraph:
#  The Investigator is obligated to perform or arrange for the conduct of supplemental measurements and/or evaluations as medically indicated or as requested by Sponsor to elucidate the nature and/or causality of the AE or SAE as fully as possible. This may include additional laboratory tests or investigations, histopathological examinations, or consultation with other health care professionals.
# 📝 Summary:
#  The Investigator is responsible for conducting or coordinating supplemental assessments, including laboratory tests, histopathological examinations, or consultations, as needed to clarify the nature and causality of AEs or SAEs, either medically indicated or requested by the Sponsor.
#
# 🟩 FIELD: U.S. FDA IND/IDE study
# 🔍 Matched Paragraph:
#  Appendix 1: Regulatory, ethical, and study oversight considerations
# 📝 Summary:
#  Summary: The study adheres to U.S. FDA IND/IDE requirements, ensuring compliance with regulatory and ethical standards. Oversight mechanisms are in place to monitor study conduct and integrity.
#
# 🟩 FIELD: FDA center (formerly IND/IDE grantor)
# 🔍 Matched Paragraph:
#  That I am aware of and will comply with Good Clinical Practise (GCP) and all applicable regulatory requirements.
# 📝 Summary:
#  FDA center (formerly IND/IDE grantor): Complies with Good Clinical Practice (GCP) and applicable regulatory requirements.
#
# 🟩 FIELD: IND/IDE number
# 🔍 Matched Paragraph:
#  An Investigator who receives an Investigator safety report describing an SAE or other specific safety information (e.g., summary or listing of SAEs) from the Sponsor will review and then file it along with the (IB/ investigational directions for use [IDFU]/package insert or state other documents) and will notify the IRB/IEC, if appropriate according to local requirements.
# 📝 Summary:
#  This paragraph does not contain an IND/IDE number.
#
# 🟩 FIELD: IND serial number
# 🔍 Matched Paragraph:
#  Participants will be allocated a unique enrolment number at the study site. This number will be retained regardless of whether the participant subsequently fulfils the eligibility criteria. If a participant withdraws from the study, the enrolment number will not be reused, and the participant will not be allowed to re-enter the study.
# 📝 Summary:
#  No numerical data provided.
#
# 🟩 FIELD: US FDA regulated drug
# 🔍 Matched Paragraph:
#  Regulatory and ethical considerations
# 📝 Summary:
#  Summary:
# The paragraph discusses regulatory and ethical considerations relevant to the clinical study, including adherence to guidelines for US FDA-regulated drugs. It emphasizes compliance with regulatory requirements and ethical standards to ensure participant safety and data integrity.
#
# 🟩 FIELD: Product exported from US
# 🔍 Matched Paragraph:
#  Seroxat [SmPC; Summary of Product Characteristics]. Brentford, UK: GSK; 2022.
# 📝 Summary:
#  Seroxat exported from the US to Brentford, UK.
#
# 🟩 FIELD: Availability of expanded access
# 🔍 Matched Paragraph:
#  Inclusion criteria
# 📝 Summary:
#  Summary: Expanded access is available for patients who meet inclusion criteria.
#
# 🟩 FIELD: Expanded access record National Clinical Trial (NCT) number
# 🔍 Matched Paragraph:
#  10.1.7.	Dissemination of Clinical Study Data	71
# 📝 Summary:
#  71
#
# 🟩 FIELD: Plan to share IPD data
# 🔍 Matched Paragraph:
#  The participant must be informed that their personal study-related data will be used by the Sponsor in accordance with local data protection law. The level of disclosure must also be explained to the participant, that their data will be used as described in the informed consent.
# 📝 Summary:
#  Participant data will be shared in compliance with local data protection laws and as outlined in the informed consent.
#
# 🟩 FIELD: url
# 🔍 Matched Paragraph:
#  PAGE
# 📝 Summary:
#  PAGE

# %%
with open("final_summaries.json", "w") as f:
    json.dump(final_summaries, f, indent=2)

upload_file("final_summaries.json", "RawOutputFiles", "raw-output")
